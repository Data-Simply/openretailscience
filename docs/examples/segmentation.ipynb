# %% [markdown]
# Overview
#
# Customer segmentation involves categorizing your customers into smaller groups based on shared characteristics such as buying habits or demographics. This helps retailers gain deeper insights into their customer base, enabling them to tailor their marketing strategies and products to meet each group's specific needs.
#
# By employing customer segmentation, companies can enhance customer satisfaction, improve targeting accuracy, and optimize resource allocation, ultimately leading to increased profitability and competitiveness in the market.
#
# In this notebook, we'll explore a few basic customer segmentations.
#
# ### Setup
#
# Here we'll load some simulated data to demonstrate the code. You do not need to know this to perform segmentations.

# %%
import matplotlib.pyplot as plt
import pandas as pd

df = pd.read_parquet("../../data/transactions.parquet")
df.head()
# Out:
#    transaction_id transaction_date transaction_time  customer_id  product_id  \
# 0           16050       2023-01-12         17:44:29            1          15
# 1           16050       2023-01-12         17:44:29            1        1317
# 2           20090       2023-02-05         09:31:42            1         509
# 3           20090       2023-02-05         09:31:42            1         735
# 4           20090       2023-02-05         09:31:42            1        1107
#
#                                product_name category_0_name  category_0_id  \
# 0                              Spawn Figure            Toys              1
# 1                                 Gone Girl           Books              8
# 2                             Ryzen 3 3300X     Electronics              3
# 3                Linden Wood Paneled Mirror            Home              5
# 4  Pro-V Daily Moisture Renewal Conditioner          Beauty              7
#
#        category_1_name  category_1_id       brand_name  brand_id  \
# 0       Action Figures              1   McFarlane Toys         3
# 1  Mystery & Thrillers             53  Alfred A. Knopf       264
# 2  Computer Components             21              AMD       102
# 3           Home Decor             30     Pottery Barn       147
# 4            Hair Care             45          Pantene       222
#
#    unit_quantity  unit_cost  unit_spend  store_id
# 0              2      36.10       55.98         6
# 1              1       6.98       10.49         6
# 2              3     200.61      360.00         4
# 3              1     379.83      599.00         4
# 4              1       3.32        4.99         4

# %% [markdown]
# Some details about the data

# %%
print(f"Number of unique customers: {df['customer_id'].nunique()}")
print(f"Number of unique transactions: {df['transaction_id'].nunique()}")
# Out:
# Number of unique customers: 4250
# Number of unique transactions: 25490

# %% [markdown]
# ## Heavy / Medium / Light
#
# Heavy, Medium, Light (HML) is a segmentation that places customers into groups based on the their percentile of spend or the number of products they bought. Heavy customers are the top 20% of customers, medium are the next 30%, and light are the bottom 50% of customers. These values are chosen based on the proportions of the Pareto distribution. Often, purchase behaviour follows this distribution. This is typified by the expression 20% of your customers generate 80% of your sales.
#
# You would use a HML segmentation to answer question such as these,
#
# * How much more are your best customers worth?
# * How much more could I spend acquiring my best customers?
# * What is the concentration of sales with my top (heavy) customers?
#
# Using OpenRetailScience it takes only one line of code to get HML segments.

# %%
from openretailscience.segmentation.hml import HMLSegmentation

seg = HMLSegmentation(df, zero_value_customers="include_with_light")
seg.df.head()
# Out:
#              unit_spend segment_name
# customer_id
# 4221               2.99        Light
# 1406               3.49        Light
# 4094               6.98        Light
# 3499               8.49        Light
# 3720               8.50        Light

# %% [markdown]
# We can then attach those segments back to the original dataframe using an ibis join or pandas merge. You can see these segments to the very right of the dataframe.

# %%
df_with_segments = df.merge(
    seg.df["segment_name"],
    left_on="customer_id",
    right_index=True,
    how="left",
)
df_with_segments.head()
# Out:
#    transaction_id transaction_date transaction_time  customer_id  product_id  \
# 0           16050       2023-01-12         17:44:29            1          15
# 1           16050       2023-01-12         17:44:29            1        1317
# 2           20090       2023-02-05         09:31:42            1         509
# 3           20090       2023-02-05         09:31:42            1         735
# 4           20090       2023-02-05         09:31:42            1        1107
#
#                                product_name category_0_name  category_0_id  \
# 0                              Spawn Figure            Toys              1
# 1                                 Gone Girl           Books              8
# 2                             Ryzen 3 3300X     Electronics              3
# 3                Linden Wood Paneled Mirror            Home              5
# 4  Pro-V Daily Moisture Renewal Conditioner          Beauty              7
#
#        category_1_name  category_1_id       brand_name  brand_id  \
# 0       Action Figures              1   McFarlane Toys         3
# 1  Mystery & Thrillers             53  Alfred A. Knopf       264
# 2  Computer Components             21              AMD       102
# 3           Home Decor             30     Pottery Barn       147
# 4            Hair Care             45          Pantene       222
#
#    unit_quantity  unit_cost  unit_spend  store_id segment_name
# 0              2      36.10       55.98         6        Light
# 1              1       6.98       10.49         6        Light
# 2              3     200.61      360.00         4        Light
# 3              1     379.83      599.00         4        Light
# 4              1       3.32        4.99         4        Light

# %% [markdown]
# Now it's only one line of code to get standard KPIs on each customer segment. This makes segment comparison easy.

# %%
from openretailscience.segmentation.segstats import SegTransactionStats

seg_stats = SegTransactionStats(df_with_segments, segment_col="segment_name")
seg_stats.df
# Out:
# /tmp/ipykernel_2929733/3584794276.py:3: FutureWarning: The calc_total parameter is deprecated and will be removed in a future version. To maintain the current behavior of including a grand total, use grouping_sets='total' or grouping_sets=[()] instead. See documentation for more flexible aggregation control with the grouping_sets parameter.
#   seg_stats = SegTransactionStats(df_with_segments, segment_col="segment_name")
#   segment_name         spend  transactions  customers   units  \
# 0        Heavy  4.518138e+07          8572        850   80558
# 1        Light  1.344912e+07          7054       2125   56523
# 2       Medium  3.045768e+07          9864       1275   86869
# 3        Total  8.908818e+07         25490       4250  223950
#
#    spend_per_customer  spend_per_transaction  transactions_per_customer  \
# 0        53154.567635            5270.809903                  10.084706
# 1         6328.995732            1906.594263                   3.319529
# 2        23888.378800            3087.761858                   7.736471
# 3        20961.925033            3495.024770                   5.997647
#
#    price_per_unit  units_per_transaction
# 0      560.855315               9.397807
# 1      237.940589               8.012900
# 2      350.616249               8.806671
# 3      397.803891               8.785798

# %% [markdown]
# We can quickly get a bar plot to compare any of the values using the `plot` function. With a few extra lines of code, we can dress up the plot with a callout. Now the chart highlights how much more valuable Heavy customers are compared to the Light ones.

# %%
from openretailscience.plots import bar
from openretailscience.plots.styles.font_utils import get_font_properties
from openretailscience.plots.styles.graph_utils import set_axis_shorthand

heavy_vs_light = seg_stats.df.set_index("segment_name")["spend"]
heavy_vs_light = heavy_vs_light[heavy_vs_light.index != "Total"]

ax = bar.plot(
    df=heavy_vs_light,
    title="What's the value of a Heavy customer?",
    x_label="",
    source_text="Source: Transaction data financial year 2023",
    sort_order="descending",
    figsize=(10, 5),
    rot=0,
)
set_axis_shorthand(ax.yaxis)

# Dress up the plot with an arrow calling out the important point
heavy_rev = seg_stats.df[seg_stats.df["segment_name"] == "Heavy"]["spend"].iloc[0]
light_rev = seg_stats.df[seg_stats.df["segment_name"] == "Light"]["spend"].iloc[0]
h_vs_l_rev = heavy_rev / light_rev
ax.annotate(
    f"The top 20% of customers\ngenerate {h_vs_l_rev:.1f}x MORE REVENUE\nthan the bottom 50%!",
    xy=(0.24, heavy_rev * 0.8),
    xytext=(0.65, heavy_rev * 0.8),
    fontsize=18,
    fontproperties=get_font_properties("poppins_regular"),
    ha="left",
    va="center",
    arrowprops={
        "facecolor": "white",
        "arrowstyle": "->",
        "connectionstyle": "arc3,rad=0.1",
    },
    color="black",
    bbox={
        "facecolor": "white",
        "edgecolor": "white",
        "boxstyle": "round,rounding_size=0.75",
        "pad": 0.75,
    },
    linespacing=1.5,
)

plt.show()

# %% [markdown]
# Getting a plot of the segment's activity over time is also now a snap.

# %%
from openretailscience.plots.time import plot

df["transaction_date"] = pd.to_datetime(df["transaction_date"])

df_with_groups = df.merge(
    seg.df["segment_name"],
    left_on="customer_id",
    right_index=True,
    how="left",
)
plot(
    df_with_groups,
    figsize=(10, 5),
    period="M",
    group_col="segment_name",
    value_col="customer_id",
    agg_func="nunique",
    title="Monthly Active Customers",
    y_label="Number of Customers",
    source_text="Source: OpenRetailScience",
)
plt.show()

# %% [markdown]
# ## Activating
#
# Once you have your segments, you will often want to activate them. It is easy to export them to a CSV for activation in your CRM or with platforms.

# %%
filename = "heavy_customers.csv"
seg.df[seg.df["segment_name"] == "Heavy"].index.to_series().to_csv(filename, index=False)

# Display the CSV
with open(filename) as f:
    print("".join(f.readlines()[:5]))
# Out:
# customer_id
# 1566
# 925
# 2095
# 1623

# %% [markdown]
# ## Coming soon
#
# * Quickly segmenting new vs returning customers
# * More charting options
# * Activating segments to Facebook and other social platforms
# * ... and more
