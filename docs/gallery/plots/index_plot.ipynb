# %% [markdown]
# # Index Plot Gallery
#
# Index plots are used for comparing different categories or segments against a baseline or average value, typically set at 100. They're ideal for retail analytics to identify which categories over- or underperform relative to the average.
#
# Index plots excel at:
# - **Performance Comparison**: Compare sales performance across product categories or regions against a baseline
# - **Segment Analysis**: Analyze customer segments against overall average behavior
# - **Benchmarking**: Evaluate stores or regions relative to company-wide metrics
# - **Opportunity Identification**: Highlight high-potential areas for growth or investment

# %%
import matplotlib.pyplot as plt
import pandas as pd

from openretailscience.plots import index

# %%
# Hand-crafted demo datasets shared across the gallery examples.
# Each dataset is designed so the chart spans both sides of the 100 baseline
# (over- and under-indexers visible together) wherever that's compatible with the option being shown.

_regional_plan = {
    "North": {"Electronics": 380, "Apparel": 200, "Home": 220, "Sports": 200},
    "Central": {"Electronics": 290, "Apparel": 230, "Home": 240, "Sports": 240},
    "West": {"Electronics": 240, "Apparel": 250, "Home": 250, "Sports": 260},
    "South": {"Electronics": 200, "Apparel": 280, "Home": 270, "Sports": 250},
    "East": {"Electronics": 150, "Apparel": 290, "Home": 290, "Sports": 270},
}
regional_sales = pd.DataFrame(
    [{"region": r, "product_category": c, "sales": v} for r, cats in _regional_plan.items() for c, v in cats.items()]
)

_quarterly_plan = {
    ("Mall", "Q1"): {"Electronics": 170, "Apparel": 240, "Home": 210, "Sports": 190, "Beauty": 190},
    ("Mall", "Q2"): {"Electronics": 175, "Apparel": 230, "Home": 215, "Sports": 195, "Beauty": 185},
    ("Mall", "Q3"): {"Electronics": 165, "Apparel": 245, "Home": 220, "Sports": 185, "Beauty": 185},
    ("Mall", "Q4"): {"Electronics": 160, "Apparel": 250, "Home": 220, "Sports": 185, "Beauty": 185},
    ("Outlet", "Q1"): {"Electronics": 200, "Apparel": 200, "Home": 200, "Sports": 200, "Beauty": 200},
    ("Outlet", "Q2"): {"Electronics": 205, "Apparel": 195, "Home": 200, "Sports": 200, "Beauty": 200},
    ("Outlet", "Q3"): {"Electronics": 195, "Apparel": 205, "Home": 200, "Sports": 200, "Beauty": 200},
    ("Outlet", "Q4"): {"Electronics": 200, "Apparel": 205, "Home": 200, "Sports": 200, "Beauty": 195},
    ("Online", "Q1"): {"Electronics": 240, "Apparel": 190, "Home": 200, "Sports": 180, "Beauty": 190},
    ("Online", "Q2"): {"Electronics": 250, "Apparel": 185, "Home": 200, "Sports": 180, "Beauty": 185},
    ("Online", "Q3"): {"Electronics": 245, "Apparel": 190, "Home": 200, "Sports": 180, "Beauty": 185},
    ("Online", "Q4"): {"Electronics": 260, "Apparel": 180, "Home": 200, "Sports": 175, "Beauty": 185},
}
quarterly_revenue = pd.DataFrame(
    [
        {"store_type": s, "quarter": q, "product_category": c, "revenue": v}
        for (s, q), values in _quarterly_plan.items()
        for c, v in values.items()
    ]
)

_aov_plan = {
    "VIP": {"Electronics": 220, "Apparel": 90, "Home": 105, "Sports": 95, "Beauty": 90},
    "Premium": {"Electronics": 175, "Apparel": 95, "Home": 110, "Sports": 100, "Beauty": 95},
    "Loyalty": {"Electronics": 110, "Apparel": 105, "Home": 100, "Sports": 100, "Beauty": 100},
    "Standard": {"Electronics": 85, "Apparel": 100, "Home": 95, "Sports": 100, "Beauty": 95},
    "Budget": {"Electronics": 45, "Apparel": 60, "Home": 55, "Sports": 60, "Beauty": 50},
}
segment_aov = pd.DataFrame(
    [
        {"customer_segment": seg, "product_category": cat, "avg_order_value": v}
        for seg, cats in _aov_plan.items()
        for cat, v in cats.items()
        for _ in range(2)
    ]
)

_region_perf_plan = {
    "North": {"Electronics": 350, "Apparel": 200, "Home": 220, "Sports": 230},
    "South": {"Electronics": 130, "Apparel": 280, "Home": 270, "Sports": 220},
    "East": {"Electronics": 200, "Apparel": 220, "Home": 320, "Sports": 260},
    "West": {"Electronics": 230, "Apparel": 250, "Home": 220, "Sports": 300},
    "Central": {"Electronics": 280, "Apparel": 240, "Home": 240, "Sports": 240},
    "Mountain": {"Electronics": 170, "Apparel": 280, "Home": 270, "Sports": 280},
    "Pacific": {"Electronics": 320, "Apparel": 220, "Home": 230, "Sports": 230},
    "Atlantic": {"Electronics": 220, "Apparel": 270, "Home": 260, "Sports": 250},
}
region_performance = pd.DataFrame(
    [
        {"region": r, "product_category": c, "performance_score": v}
        for r, cats in _region_perf_plan.items()
        for c, v in cats.items()
    ]
)

_dept_plan = {
    "Sales": {"Electronics": 280, "Apparel": 200, "Home": 200, "Sports": 200, "Beauty": 160},
    "IT": {"Electronics": 240, "Apparel": 210, "Home": 200, "Sports": 200, "Beauty": 200},
    "Customer Service": {"Electronics": 220, "Apparel": 200, "Home": 200, "Sports": 200, "Beauty": 200},
    "Operations": {"Electronics": 200, "Apparel": 210, "Home": 200, "Sports": 210, "Beauty": 200},
    "HR": {"Electronics": 180, "Apparel": 220, "Home": 200, "Sports": 200, "Beauty": 220},
    "Marketing": {"Electronics": 150, "Apparel": 230, "Home": 220, "Sports": 220, "Beauty": 220},
}
dept_efficiency = pd.DataFrame(
    [
        {"department": d, "product_category": c, "efficiency_metric": v}
        for d, cats in _dept_plan.items()
        for c, v in cats.items()
    ]
)

_subcat_plan = {
    "Smartphones": {"Electronics": 380, "Apparel": 100, "Home": 110, "Sports": 100, "Beauty": 110},
    "Audio": {"Electronics": 340, "Apparel": 110, "Home": 120, "Sports": 110, "Beauty": 120},
    "Gaming": {"Electronics": 320, "Apparel": 110, "Home": 130, "Sports": 130, "Beauty": 110},
    "Tablets": {"Electronics": 290, "Apparel": 120, "Home": 130, "Sports": 130, "Beauty": 130},
    "Wearables": {"Electronics": 270, "Apparel": 150, "Home": 130, "Sports": 150, "Beauty": 100},
    "Cameras": {"Electronics": 250, "Apparel": 130, "Home": 150, "Sports": 170, "Beauty": 100},
    "Smart Home": {"Electronics": 230, "Apparel": 130, "Home": 220, "Sports": 110, "Beauty": 110},
    "Laptops": {"Electronics": 210, "Apparel": 130, "Home": 160, "Sports": 130, "Beauty": 170},
    "Furniture": {"Electronics": 90, "Apparel": 220, "Home": 320, "Sports": 180, "Beauty": 190},
    "Apparel Sets": {"Electronics": 80, "Apparel": 340, "Home": 180, "Sports": 200, "Beauty": 200},
    "Fitness Gear": {"Electronics": 70, "Apparel": 220, "Home": 160, "Sports": 360, "Beauty": 190},
    "Beauty Kits": {"Electronics": 60, "Apparel": 200, "Home": 180, "Sports": 180, "Beauty": 380},
}
subcategory_volume = pd.DataFrame(
    [
        {"product_subcategory": s, "product_category": c, "sales_volume": v}
        for s, cats in _subcat_plan.items()
        for c, v in cats.items()
    ]
)

_london_plan = {
    "Camden": {"Electronics": 320, "Apparel": 220, "Home": 220, "Sports": 220, "Beauty": 220},
    "Shoreditch": {"Electronics": 300, "Apparel": 220, "Home": 220, "Sports": 220, "Beauty": 220},
    "Brixton": {"Electronics": 270, "Apparel": 230, "Home": 220, "Sports": 230, "Beauty": 230},
    "Clapham": {"Electronics": 240, "Apparel": 240, "Home": 240, "Sports": 230, "Beauty": 230},
    "Islington": {"Electronics": 230, "Apparel": 240, "Home": 240, "Sports": 230, "Beauty": 240},
    "Notting Hill": {"Electronics": 220, "Apparel": 250, "Home": 240, "Sports": 230, "Beauty": 240},
    "Hackney": {"Electronics": 190, "Apparel": 250, "Home": 240, "Sports": 240, "Beauty": 240},
    "Greenwich": {"Electronics": 170, "Apparel": 250, "Home": 250, "Sports": 240, "Beauty": 240},
    "Wimbledon": {"Electronics": 140, "Apparel": 260, "Home": 250, "Sports": 250, "Beauty": 250},
    "Stratford": {"Electronics": 110, "Apparel": 270, "Home": 260, "Sports": 250, "Beauty": 260},
}
london_stores = pd.DataFrame(
    [
        {"store_location": s, "product_category": c, "sales_performance": v}
        for s, cats in _london_plan.items()
        for c, v in cats.items()
    ]
)

_channels_plan = {
    "E-commerce": {"Electronics": 380, "Apparel": 220, "Home": 200, "Sports": 200, "Beauty": 200},
    "Mobile App": {"Electronics": 360, "Apparel": 220, "Home": 200, "Sports": 200, "Beauty": 220},
    "Social Commerce": {"Electronics": 340, "Apparel": 230, "Home": 210, "Sports": 200, "Beauty": 220},
    "Marketplace": {"Electronics": 320, "Apparel": 230, "Home": 220, "Sports": 210, "Beauty": 220},
    "Retail Stores": {"Electronics": 200, "Apparel": 240, "Home": 230, "Sports": 230, "Beauty": 230},
    "Wholesale": {"Electronics": 180, "Apparel": 250, "Home": 240, "Sports": 240, "Beauty": 240},
    "Franchise": {"Electronics": 160, "Apparel": 250, "Home": 250, "Sports": 240, "Beauty": 250},
    "Direct Sales": {"Electronics": 150, "Apparel": 260, "Home": 250, "Sports": 250, "Beauty": 250},
}
sales_channels = pd.DataFrame(
    [
        {"sales_channel": s, "product_category": c, "performance_metric": v}
        for s, cats in _channels_plan.items()
        for c, v in cats.items()
    ]
)

_market_plan = {
    "North America": {"Electronics": 350, "Apparel": 200, "Home": 220, "Sports": 230, "Beauty": 200},
    "Europe": {"Electronics": 240, "Apparel": 280, "Home": 240, "Sports": 220, "Beauty": 230},
    "Asia Pacific": {"Electronics": 280, "Apparel": 230, "Home": 270, "Sports": 220, "Beauty": 200},
    "Latin America": {"Electronics": 200, "Apparel": 240, "Home": 220, "Sports": 220, "Beauty": 220},
    "Middle East": {"Electronics": 220, "Apparel": 230, "Home": 230, "Sports": 220, "Beauty": 220},
    "Africa": {"Electronics": 180, "Apparel": 240, "Home": 220, "Sports": 220, "Beauty": 220},
}
market_regions = pd.DataFrame(
    [
        {"market_region": r, "product_category": c, "market_share": v}
        for r, cats in _market_plan.items()
        for c, v in cats.items()
    ]
)

_cust_plan = {
    "Regular": {"Electronics": 220, "Apparel": 240, "Home": 230, "Sports": 230, "Beauty": 230},
    "Premium": {"Electronics": 280, "Apparel": 220, "Home": 220, "Sports": 220, "Beauty": 220},
    "VIP": {"Electronics": 320, "Apparel": 200, "Home": 210, "Sports": 220, "Beauty": 200},
    "Corporate": {"Electronics": 290, "Apparel": 220, "Home": 220, "Sports": 220, "Beauty": 200},
    "Wholesale": {"Electronics": 200, "Apparel": 240, "Home": 240, "Sports": 230, "Beauty": 230},
    "Employee": {"Electronics": 240, "Apparel": 230, "Home": 230, "Sports": 230, "Beauty": 220},
    "Test": {"Electronics": 50, "Apparel": 10, "Home": 10, "Sports": 10, "Beauty": 10},
    "Internal": {"Electronics": 20, "Apparel": 20, "Home": 20, "Sports": 20, "Beauty": 20},
}
customer_types = pd.DataFrame(
    [
        {"customer_type": ct, "product_category": c, "revenue_contribution": v}
        for ct, cats in _cust_plan.items()
        for c, v in cats.items()
    ]
)

# %% [markdown]
# ## Basic Index Plot
#
# The simplest call: pick a baseline category (`value_to_index="Electronics"`) and the plot computes each group's share of that category versus its share of overall volume. Bars to the right of 100 over-index the baseline category; bars to the left under-index it.
#
# Setting `sort_by="value"` (rather than the alphabetical default) puts the strongest over-indexer at the top so the eye lands on the headline first.
#
# ---

# %%
index.plot(
    regional_sales,
    value_col="sales",
    group_col="region",
    index_col="product_category",
    value_to_index="Electronics",
    sort_by="value",
    sort_order="ascending",
    eyebrow="Regional performance",
    title="North leads Electronics share by 90 index points over East",
    subtitle="Sales index by region, baseline of 100 set by Electronics",
    x_label="Index",
)
plt.show()

# %% [markdown]
# ## Multiple Series Index Plot
#
# Pass `series_col` to break each group into a stacked set of bars — one per series value (e.g. one bar per quarter, per store type). Useful for tracking how each group's index moves across time periods or segments.
#
# Note: `sort_by="value"` is unsupported here because there's no single value to sort on (each group has multiple), so groups stay in the data's natural order.
#
# ---

# %%
index.plot(
    quarterly_revenue,
    value_col="revenue",
    group_col="store_type",
    index_col="product_category",
    value_to_index="Electronics",
    series_col="quarter",
    eyebrow="Channel mix",
    title="Online captures more Electronics share each quarter while Mall slips",
    subtitle="Performance index by store type and quarter, baseline of 100 set by Electronics",
    x_label="Index",
    legend_title="Quarter",
    move_legend_outside=True,
)
plt.show()

# %% [markdown]
# ## Different Aggregation Function
#
# Use `agg_func="mean"` to index on the average value per group rather than the sum. Pick this when row counts differ between groups and you care about the per-row magnitude — e.g. average order value across customer segments — rather than total volume.
#
# Other supported functions: `"max"`, `"min"`, `"nunique"`. Default is `"sum"`.
#
# ---

# %%
index.plot(
    segment_aov,
    value_col="avg_order_value",
    group_col="customer_segment",
    index_col="product_category",
    value_to_index="Electronics",
    agg_func="mean",
    sort_by="value",
    sort_order="ascending",
    eyebrow="Customer segments",
    title="VIP and Premium spend disproportionately on Electronics; Budget barely touches it",
    subtitle="Mean order value index by customer segment, baseline of 100 set by Electronics",
    x_label="Index",
)
plt.show()

# %% [markdown]
# ## Sort Order: Worst-First
#
# Pair `sort_by="value"` with `sort_order="descending"` to flip the default leaderboard. The lowest indexes land at the top — useful when the chart's job is triage rather than celebration, and you want the eye to land on the worst case first.
#
# ---

# %%
# sort_order="descending" puts the lowest indexes at the top — useful for triaging underperformers.
index.plot(
    region_performance,
    value_col="performance_score",
    group_col="region",
    index_col="product_category",
    value_to_index="Electronics",
    sort_by="value",
    sort_order="descending",
    eyebrow="Regional ranking",
    title="South and Mountain need the most attention on Electronics performance",
    subtitle="Performance index by region, ranked worst-first, baseline of 100 set by Electronics",
    x_label="Index",
)
plt.show()

# %% [markdown]
# ## Custom Highlight Range
#
# The shaded band marks an "acceptable" performance range. The default is `(80, 120)`; tighten it (e.g. `(90, 110)`) when small deviations matter, or widen it when you only care about extremes. Bars whose tips fall outside the band stand out visually as the ones that need attention.
#
# ---

# %%
index.plot(
    dept_efficiency,
    value_col="efficiency_metric",
    group_col="department",
    index_col="product_category",
    value_to_index="Electronics",
    sort_by="value",
    sort_order="ascending",
    highlight_range=(90, 110),
    eyebrow="Efficiency",
    title="Three of six departments fall outside the tighter 90 to 110 efficiency band",
    subtitle="Efficiency index by department, baseline of 100 set by Electronics",
    x_label="Index",
)
plt.show()

# %% [markdown]
# ## Color by Threshold
#
# With `color_by_threshold=True`, bars get colored by where they fall relative to `highlight_range`: ≥ the upper threshold uses `plot.color.positive` (green by default), ≤ the lower threshold uses `plot.color.negative` (red), and anything in between uses `plot.color.neutral` (gray). Skips the need for the reader to compare bar tips to the band — color does the work.
#
# ---

# %%
index.plot(
    region_performance,
    value_col="performance_score",
    group_col="region",
    index_col="product_category",
    value_to_index="Electronics",
    sort_by="value",
    sort_order="ascending",
    color_by_threshold=True,
    eyebrow="Regional ranking",
    title="Color flags which regions clear the 80 to 120 performance band",
    subtitle="Performance index by region, color-coded by threshold, baseline of 100 set by Electronics",
    x_label="Index",
)
plt.show()

# %% [markdown]
# ## Top N Filtering
#
# Pass `top_n=N` to keep only the N highest-indexing groups. Useful when there are too many groups to fit comfortably and you only care about the leaders. Combine with `sort_by="value"` and `sort_order="ascending"` to put the strongest at the top of the chart.
#
# ---

# %%
index.plot(
    subcategory_volume,
    value_col="sales_volume",
    group_col="product_subcategory",
    index_col="product_category",
    value_to_index="Electronics",
    top_n=8,
    sort_by="value",
    sort_order="ascending",
    eyebrow="Subcategory leaders",
    title="Top 8 subcategories all over-index Electronics",
    subtitle="Sales volume index, top 8 subcategories shown, baseline of 100 set by Electronics",
    x_label="Index",
    source_text="Source: Product Sales Database - Q4 2024",
)
plt.show()

# %% [markdown]
# ## Bottom N Filtering
#
# Mirror of `top_n` — `bottom_n=N` keeps only the N lowest-indexing groups. Pair with `sort_order="descending"` to surface the worst case at the top of the chart for triage. You can use `top_n` and `bottom_n` together to show the extremes and drop everything in the middle.
#
# ---

# %%
index.plot(
    london_stores,
    value_col="sales_performance",
    group_col="store_location",
    index_col="product_category",
    value_to_index="Electronics",
    bottom_n=4,
    sort_by="value",
    sort_order="descending",
    eyebrow="Underperformers",
    title="Four outer-London locations under-index Electronics by 12 to 50 points",
    subtitle="Sales performance index, bottom 4 locations shown, baseline of 100 set by Electronics",
    x_label="Index",
)
plt.show()

# %% [markdown]
# ## Filter by Threshold
#
# `filter_above=N` keeps only groups whose raw index exceeds N (e.g. `filter_above=115` keeps groups indexing above 115); `filter_below=N` is the mirror, keeping only groups whose raw index is below N. Both thresholds are expressed in the same units as the chart axis, so 100 is the baseline and 120 reads as "20 points above". Use them to surface the standouts on either end and hide everything close to baseline.
#
# The two parameters AND together when combined, so you can't get *both* extremes in a single chart — render two charts side by side instead, one per direction. (Pair `filter_below` with `sort_order="descending"` to put the worst case at the top.)
#
# ---

# %%
index.plot(
    sales_channels,
    value_col="performance_metric",
    group_col="sales_channel",
    index_col="product_category",
    value_to_index="Electronics",
    filter_above=115,
    sort_by="value",
    sort_order="ascending",
    eyebrow="Channel ranking",
    title="All four digital channels over-index Electronics by 15 or more points",
    subtitle="Performance index, channels indexing above 115, baseline of 100 set by Electronics",
    x_label="Index",
)
plt.show()

# %%
index.plot(
    sales_channels,
    value_col="performance_metric",
    group_col="sales_channel",
    index_col="product_category",
    value_to_index="Electronics",
    filter_below=80,
    sort_by="value",
    sort_order="descending",
    eyebrow="Channel ranking",
    title="All four traditional channels under-index Electronics by 20 or more points",
    subtitle="Performance index, channels indexing below 80, baseline of 100 set by Electronics",
    x_label="Index",
)
plt.show()

# %% [markdown]
# ## Include Only Specific Groups
#
# Pass `include_only_groups=[...]` to restrict the chart to a hand-picked subset of group values. Useful when the underlying data covers many regions/channels/segments but the analysis is about a specific competitive set, geography, or peer group. Anything not in the list is silently dropped before plotting.
#
# ---

# %%
index.plot(
    market_regions,
    value_col="market_share",
    group_col="market_region",
    index_col="product_category",
    value_to_index="Electronics",
    include_only_groups=["North America", "Europe", "Asia Pacific", "Latin America"],
    sort_by="value",
    sort_order="ascending",
    eyebrow="Market regions",
    title="North America leads Electronics share; Latin America trails the other three majors",
    subtitle="Market share index by region, baseline of 100 set by Electronics",
    x_label="Index",
)
plt.show()

# %% [markdown]
# ## Exclude Specific Groups
#
# Pass `exclude_groups=[...]` to drop specific group values from the chart. Useful for keeping out test/internal segments, deprecated regions, or any outliers that distort the visual. Everything else is kept.
#
# ---

# %%
index.plot(
    customer_types,
    value_col="revenue_contribution",
    group_col="customer_type",
    index_col="product_category",
    value_to_index="Electronics",
    exclude_groups=["Test", "Internal"],
    sort_by="value",
    sort_order="ascending",
    eyebrow="Customer types",
    title="VIP and Corporate customers skew toward Electronics; Wholesale skews away",
    subtitle="Revenue contribution index by customer type, test data excluded, baseline of 100 set by Electronics",
    x_label="Index",
)
plt.show()
